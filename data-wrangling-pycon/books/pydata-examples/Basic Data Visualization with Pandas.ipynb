# %%
import pandas as pd
import numpy as np

# %%
# %pylab inline
# Out:
# /home/markus/miniconda3/envs/conda_dw34/lib/python3.4/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/markus/miniconda3/envs/conda_dw34/lib/python3.4/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot()

# %%
df.plot.bar()

# %%
df.plot.bar(stacked=True)

# %%
df.plot.hist()

# %%
df.plot.hist(bins=20, stacked=True)

# %%
df
# Out:
#           a         b         c         d
# 0  0.596717  0.982865  0.187572  0.726086
# 1  0.633271  0.944896  0.688597  0.898978
# 2  0.152350  0.490363  0.481838  0.576390
# 3  0.212432  0.371948  0.078969  0.074464
# 4  0.107409  0.843815  0.318613  0.059174
# 5  0.445529  0.128754  0.969706  0.659179
# 6  0.729191  0.990162  0.951093  0.114635
# 7  0.540427  0.060782  0.454033  0.572899
# 8  0.394770  0.811230  0.375680  0.972707
# 9  0.270197  0.981773  0.520982  0.191139

# %%
df.diff()
# Out:
#           a         b         c         d
# 0       NaN       NaN       NaN       NaN
# 1  0.036554 -0.037969  0.501025  0.172892
# 2 -0.480921 -0.454532 -0.206759 -0.322588
# 3  0.060082 -0.118415 -0.402869 -0.501926
# 4 -0.105023  0.471867  0.239645 -0.015290
# 5  0.338119 -0.715061  0.651092  0.600004
# 6  0.283662  0.861408 -0.018613 -0.544544
# 7 -0.188764 -0.929379 -0.497059  0.458264
# 8 -0.145657  0.750448 -0.078353  0.399808
# 9 -0.124573  0.170543  0.145302 -0.781569

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a8a94fe48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6a8a833748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a8a7fbc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6a8a7b86a0>]], dtype=object)

# %%
df.diff?

# %%
df.plot.box()

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange', medians='DarkBlue', caps='Gray')

# %%
df.plot.box(color=color, sym='r+')

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
df.plot(legend=False)

# %% [markdown]
# #### [Even *more* examples and documentation](http://pandas.pydata.org/pandas-docs/stable/visualization.html)
