# %%
import pandas as pd

# %%
from pandas_datareader import data

# %%
from datetime import datetime

# %%
data.DataReader?

# %%
facebook = data.DataReader('FB', 'yahoo', datetime(2007,1, 1), datetime(2016, 1, 1))

# %%
facebook.head()
# Out:
#                  Open       High        Low      Close     Volume  Adj Close
# Date
# 2012-05-18  42.049999  45.000000  38.000000  38.230000  573576400  38.230000
# 2012-05-21  36.529999  36.660000  33.000000  34.029999  168192700  34.029999
# 2012-05-22  32.610001  33.590000  30.940001  31.000000  101786600  31.000000
# 2012-05-23  31.370001  32.500000  31.360001  32.000000   73600000  32.000000
# 2012-05-24  32.950001  33.209999  31.770000  33.029999   50237200  33.029999

# %%
google = data.DataReader('GOOGL', 'yahoo', datetime(2007,1, 1), datetime(2016, 1, 1))

# %%
tesla = data.get_data_yahoo('TL0')

# %%
tesla.head()
# Out:
#               Open    High     Low   Close  Volume  Adj Close
# Date
# 2010-06-30  22.515  24.360  20.200  22.515    7700     22.515
# 2010-07-01  19.945  20.405  16.455  16.960    3100     16.960
# 2010-07-02  17.770  18.060  17.770  18.060    1600     18.060
# 2010-07-05  15.370  15.455  15.290  15.290     400     15.290
# 2010-07-06  15.225  15.755  14.445  14.445    2500     14.445

# %%
google['Stock'] = 'GOOGL'

# %%
facebook['Stock'] = 'FB'

# %%
tesla['Stock'] = 'TZL'

# %%
google['Stock'] = 'GOOGL'
facebook['Stock'] = 'FB'
tesla['Stock'] = 'TZL'
merged = pd.concat([google, facebook, tesla])

# %%
pd.concat([google, facebook, tesla])
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2007-01-03  466.000001  476.660015  461.109998  467.589992  15397500
# 2007-01-04  469.000019  483.950020  468.350004  483.260006  15759400
# 2007-01-05  482.499994  487.499994  478.110010  487.190002  13730400
# 2007-01-08  487.690020  489.869998  482.200002  483.579999   9499200
# 2007-01-09  485.450014  488.250007  481.199996  485.500013  10752000
# 2007-01-10  484.430008  493.549999  482.040006  489.460008  11925000
# 2007-01-11  497.200002  501.750013  496.179996  499.720001  14401900
# 2007-01-12  501.990007  504.999994  499.999994  504.999994   8938400
# 2007-01-16  507.549993  512.999982  503.300005  504.280012  15122600
# 2007-01-17  503.390003  507.770018  494.380009  497.280000  13384800
# 2007-01-18  494.520006  496.480019  487.429996  487.830017  11852100
# 2007-01-19  487.980013  490.760006  486.740013  489.750000   9946600
# ...

# %%
merged = pd.concat([google, facebook, tesla])

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
merged['Adj Close'].plot()

# %%
merged.describe()
pd.DataFrame.describe?

# %%
merged['High'] > 1200
# Out:
# Date
# 2007-01-03    False
# 2007-01-04    False
# 2007-01-05    False
# 2007-01-08    False
# 2007-01-09    False
# 2007-01-10    False
# 2007-01-11    False
# 2007-01-12    False
# 2007-01-16    False
# 2007-01-17    False
# 2007-01-18    False
# 2007-01-19    False
# 2007-01-22    False
# 2007-01-23    False
# 2007-01-24    False
# 2007-01-25    False
# 2007-01-26    False
# 2007-01-29    False
# 2007-01-30    False
# 2007-01-31    False
# 2007-02-01    False
# 2007-02-02    False
# 2007-02-05    False
# 2007-02-06    False
# 2007-02-07    False
# 2007-02-08    False
# 2007-02-09    False
# 2007-02-12    False
# 2007-02-13    False
# 2007-02-14    False
#               ...
# 2015-11-18    False
# 2015-11-19    False
# 2015-11-20    False
# 2015-11-23    False
# 2015-11-24    False
# 2015-11-25    False
# 2015-11-27    False
# 2015-11-30    False
# 2015-12-01    False
# 2015-12-02    False
# 2015-12-03    False
# 2015-12-04    False
# 2015-12-07    False
# 2015-12-08    False
# ...

# %%
t_low = merged.loc[merged[merged['Stock']=='GOOGL']['Low'].idxmin()]
print(t_low)

print('\n\n')
new = merged[merged['Stock']=='GOOGL']['Low']
#print(new)
#print('\n\n')

# new = merged.loc[merged['Stock']=='GOOGL','Low']
# Out:
# Open           262.51
# High           269.37
# Low             247.3
# Close          262.43
# Volume       20468500
# Adj Close     131.346
# Stock           GOOGL
# Name: 2008-11-21 00:00:00, dtype: object
# Date
# 2007-01-03    461.109998
# 2007-01-04    468.350004
# 2007-01-05    478.110010
# 2007-01-08    482.200002
# 2007-01-09    481.199996
# 2007-01-10    482.040006
# 2007-01-11    496.179996
# 2007-01-12    499.999994
# 2007-01-16    503.300005
# 2007-01-17    494.380009
# 2007-01-18    487.429996
# 2007-01-19    486.740013
# 2007-01-22    478.500001
# 2007-01-23    477.290000
# 2007-01-24    483.290006
# 2007-01-25    485.660009
# 2007-01-26    487.030006
# 2007-01-29    490.500013
# 2007-01-30    491.219995
# 2007-01-31    495.510012
# 2007-02-01    481.530018
# 2007-02-02    477.810017
# 2007-02-05    466.189996
# 2007-02-06    467.260000
# 2007-02-07    468.779994
# 2007-02-08    465.149991
# 2007-02-09    461.500019
# 2007-02-12    455.019994
# ...

# %%
tzl_index = merged.loc[merged[merged['Stock']=='TZL']['Low'].idxmin()].index
print(tzl_index)

line = merged.index.get_loc(tzl_index)
print(line)

col = merged.columns.get_loc('Stock')
print(col)
# Out:
# DatetimeIndex(['2010-07-07', '2010-07-07'], dtype='datetime64[ns]', name='Date', freq=None)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/donal/cyberdyne/rejewski/lib/python3.5/site-packages/pandas/tseries/index.py in get_loc(self, key, method, tolerance)
#    1410         try:
# -> 1411             return Index.get_loc(self, key, method, tolerance)
#    1412         except (KeyError, ValueError, TypeError):
#
# /home/donal/cyberdyne/rejewski/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2103             try:
# -> 2104                 return self._engine.get_loc(key)
#    2105             except KeyError:
#
# pandas/index.pyx in pandas.index.DatetimeEngine.get_loc (pandas/index.c:11241)()
#
# pandas/index.pyx in pandas.index.DatetimeEngine.get_loc (pandas/index.c:10525)()
#
# TypeError:
#
# ...

# %%
merged[merged['High'] > 1200]
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2014-02-14  1195.609971  1204.390001  1192.800040  1202.800040  4369000
# 2014-02-18  1201.410074  1212.870038  1199.999986  1210.879965  4213500
# 2014-02-19  1205.299979  1209.220005  1197.500047  1202.340051  4202900
# 2014-02-20  1203.140031  1206.890062  1200.219981  1204.110008  3398100
# 2014-02-21  1207.810039  1209.869989  1202.840039  1203.790016  3720800
# 2014-02-24  1205.359977  1220.159982  1205.099984  1212.510047  3345200
# 2014-02-25  1215.939963  1224.499998  1210.419976  1219.999986  2874500
# 2014-02-26  1224.000010  1228.880013  1213.760016  1220.169982  3960400
# 2014-02-27  1218.390025  1224.230005  1217.010059  1219.210005  2517400
# 2014-02-28  1220.339978  1224.190006  1206.219956  1215.649970  4622500
# 2014-03-03  1206.750065  1207.840039  1192.140056  1202.690042  4205300
# 2014-03-04  1214.999986  1215.999962  1209.499998  1214.909988  2932400
# ...

# %%
merged.to_excel('../../data/stocks.xlsx')

# %% [markdown]
# ### Grab another stock and merge it in! Find the lowest date for each stock you have in the dataframe.
#
# Try it yourself first, then compare to my solution. With Pandas there are *many* ways to solve the problem, plenty of them great!

# %%
# %load solutions/stocks_solution.py
