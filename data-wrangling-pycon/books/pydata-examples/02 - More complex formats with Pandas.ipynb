# %%
import pandas as pd

# %%
import pdftables

# %%
pdftables.get_tables?

# %%
pdftables.page_to_tables?

# %%
my_pdf = open('../../data/WEF_GlobalCompetitivenessReport_2014-15.pdf', 'rb')

# %%
open?

# %%
chart_page = pdftables.get_pdf_page(my_pdf, 29)

# %%
chart_page
# Out:
# <LTPage(1) 0.000,0.000,595.276,841.890 rotate=0>

# %%
table = pdftables.page_to_tables(chart_page)

# %%
table
# Out:
# ([['',
#    '',
#    '',
#    'Rank among ',
#    'GCI 2013–',
#    '',
#    '',
#    '',
#    'Rank among ',
#    'GCI 2013–'],
#   ['Country/Economy',
#    'Rank (out of 144)',
#    'Score  (1–7)',
#    '2013–2014 economies*',
#    '2014 rank  (out of 148)†',
#    'Country/Economy',
#    'Rank (out of 144)',
#    'Score  (1–7)',
#    '2013–2014 economies*',
#    '2014 rank  (out of 148)†'],
#   ['Switzerland',
#    '1',
#    '5.70',
#    '1',
#    '1',
#    'Sri Lanka',
#    '73',
#    '4.19',
#    '73',
#    '65'],
#   ['Singapore', '2', '5.65', '2', '2', 'Botswana', '74', '4.15', '74', '74'],
#   ['United States',
#    '3',
#    '5.54',
#    '3',
#    '5',
#    'Slovak Republic',
#    '75',
#    '4.15',
#    '75',
#    '78'],
#   ['Finland', '4', '5.50', '4', '3', 'Ukraine', '76', '4.14', '76', '84'],
#   ['Germany', '5', '5.49', '5', '4', 'Croatia', '77', '4.13', '77', '75'],
#   ['Japan', '6', '5.47', '6', '9', 'Guatemala', '78', '4.10', '78', '86'],
#   ['Hong Kong SAR',
#    '7',
#    '5.46',
#    '7',
#    '7',
#    'Algeria',
#    '79',
#    '4.08',
#    '79',
#    '100'],
#   ['Netherlands', '8', '5.45', '8', '8', 'Uruguay', '80', '4.04', '80', '85'],
#   ['United Kingdom',
#    '9',
#    '5.41',
#    '9',
#    '10',
#    'Greece',
#    '81',
#    '4.04',
#    '81',
#    '91'],
#   ['Sweden', '10', '5.41', '10', '6', 'Moldova', '82', '4.03', '82', '89'],
#   ['Norway',
#    '11',
#    '5.35',
#    '11',
#    '11',
#    'Iran, Islamic Rep.',
#    '83',
#    '4.03',
#    '83',
#    '82'],
#   ['United Arab Emirates',
#    '12',
#    '5.33',
#    '12',
#    '19',
#    'El Salvador',
#    '84',
#    '4.01',
#    '84',
#    '97'],
#   ['Denmark', '13', '5.29', '13', '15', 'Armenia', '85', '4.01', '85', '79'],
#   ['Taiwan, China',
#    '14',
#    '5.25',
#    '14',
#    '12',
#    'Jamaica',
#    '86',
#    '3.98',
#    '86',
#    '94'],
#   ['Canada', '15', '5.24', '15', '14', 'Tunisia', '87', '3.96', '87', '83'],
#   ['Qatar', '16', '5.24', '16', '13', 'Namibia', '88', '3.96', '88', '90'],
#   ['New Zealand',
#    '17',
#    '5.20',
#    '17',
#    '18',
#    'Trinidad and Tobago',
#    '89',
#    '3.95',
#    '89',
#    '92'],
#   ['Belgium', '18', '5.18', '18', '17', 'Kenya', '90', '3.93', '90', '96'],
#   ['Luxembourg',
#    '19',
#    '5.17',
#    '19',
#    '22',
#    'Tajikistan',
#    '91',
#    '3.93',
#    'n/a',
#    'n/a'],
#   ['Malaysia',
#    '20',
#    '5.16',
#    '20',
#    '24',
#    'Seychelles',
#    '92',
#    '3.91',
#    '91',
#    '80'],
#   ['Austria', '21', '5.16', '21', '16', 'Lao PDR', '93', '3.91', '92', '81'],
#   ['Australia', '22', '5.08', '22', '21', 'Serbia', '94', '3.90', '93', '101'],
#   ['France', '23', '5.08', '23', '23', 'Cambodia', '95', '3.89', '94', '88'],
#   ['Saudi Arabia',
#    '24',
#    '5.06',
#    '24',
#    '20',
#    'Zambia',
#    '96',
#    '3.86',
#    '95',
#    '93'],
#   ['Ireland', '25', '4.98', '25', '28', 'Albania', '97', '3.84', '96', '95'],
#   ['Korea, Rep.',
#    '26',
#    '4.96',
#    '26',
#    '25',
#    'Mongolia',
#    '98',
#    '3.83',
#    '97',
#    '107'],
#   ['Israel', '27', '4.95', '27', '27', 'Nicaragua', '99', '3.82', '98', '99'],
#   ['China', '28', '4.89', '28', '29', 'Honduras', '100', '3.82', '99', '111'],
#   ['Estonia',
#    '29',
#    '4.71',
#    '29',
#    '32',
#    'Dominican Republic',
#    '101',
#    '3.82',
#    '100',
#    '105'],
#   ['Iceland', '30', '4.71', '30', '31', 'Nepal', '102', '3.81', '101', '117'],
#   ['Thailand',
#    '31',
#    '4.66',
#    '31',
#    '37',
#    'Bhutan',
#    '103',
#    '3.80',
#    '102',
#    '109'],
#   ['Puerto Rico',
#    '32',
#    '4.64',
#    '32',
#    '30',
#    'Argentina',
#    '104',
#    '3.79',
#    '103',
#    '104'],
#   ['Chile', '33', '4.60', '33', '34', 'Bolivia', '105', '3.77', '104', '98'],
#   ['Indonesia',
#    '34',
#    '4.57',
#    '34',
#    '38',
#    'Gabon',
#    '106',
#    '3.74',
#    '105',
#    '112'],
#   ['Spain', '35', '4.55', '35', '35', 'Lesotho', '107', '3.73', '106', '123'],
#   ['Portugal',
#    '36',
#    '4.54',
#    '36',
#    '51',
#    'Kyrgyz Republic',
#    '108',
#    '3.73',
#    '107',
#    '121'],
#   ['Czech Republic',
#    '37',
#    '4.53',
#    '37',
#    '46',
#    'Bangladesh',
#    '109',
#    '3.72',
#    '108',
#    '110'],
#   ['Azerbaijan',
#    '38',
#    '4.53',
#    '38',
#    '39',
#    'Suriname',
#    '110',
#    '3.71',
#    '109',
#    '106'],
#   ['Mauritius',
#    '39',
#    '4.52',
#    '39',
#    '45',
#    'Ghana',
#    '111',
#    '3.71',
#    '110',
#    '114'],
#   ['Kuwait', '40', '4.51', '40', '36', 'Senegal', '112', '3.70', '111', '113'],
#   ['Lithuania',
#    '41',
#    '4.51',
#    '41',
#    '48',
#    'Lebanon',
#    '113',
#    '3.68',
#    '112',
#    '103'],
#   ['Latvia',
#    '42',
#    '4.50',
#    '42',
#    '52',
#    'Cape Verde',
#    '114',
#    '3.68',
#    '113',
#    '122'],
#   ['Poland',
#    '43',
#    '4.48',
#    '43',
#    '42',
#    "Côte d'Ivoire",
#    '115',
#    '3.67',
#    '114',
#    '126'],
#   ['Bahrain',
#    '44',
#    '4.48',
#    '44',
#    '43',
#    'Cameroon',
#    '116',
#    '3.66',
#    '115',
#    '115'],
#   ['Turkey', '45', '4.46', '45', '44', 'Guyana', '117', '3.65', '116', '102'],
#   ['Oman', '46', '4.46', '46', '33', 'Ethiopia', '118', '3.60', '117', '127'],
#   ['Malta', '47', '4.45', '47', '41', 'Egypt', '119', '3.60', '118', '118'],
#   ['Panama',
#    '48',
#    '4.43',
#    '48',
#    '40',
#    'Paraguay',
#    '120',
#    '3.59',
#    '119',
#    '119'],
#   ['Italy', '49', '4.42', '49', '49', 'Tanzania', '121', '3.57', '120', '125'],
#   ['Kazakhstan',
#    '50',
#    '4.42',
#    '50',
#    '50',
#    'Uganda',
#    '122',
#    '3.56',
#    '121',
#    '129'],
#   ['Costa Rica',
#    '51',
#    '4.42',
#    '51',
#    '54',
#    'Swaziland',
#    '123',
#    '3.55',
#    '122',
#    '124'],
#   ['Philippines',
#    '52',
#    '4.40',
#    '52',
#    '59',
#    'Zimbabwe',
#    '124',
#    '3.54',
#    '123',
#    '131'],
#   ['Russian Federation',
#    '53',
#    '4.37',
#    '53',
#    '64',
#    'Gambia, The',
#    '125',
#    '3.53',
#    '124',
#    '116'],
#   ['Bulgaria', '54', '4.37', '54', '57', 'Libya', '126', '3.48', '125', '108'],
#   ['Barbados',
#    '55',
#    '4.36',
#    '55',
#    '47',
#    'Nigeria',
#    '127',
#    '3.44',
#    '126',
#    '120'],
#   ['South Africa',
#    '56',
#    '4.35',
#    '56',
#    '53',
#    'Mali',
#    '128',
#    '3.43',
#    '127',
#    '135'],
#   ['Brazil',
#    '57',
#    '4.34',
#    '57',
#    '56',
#    'Pakistan',
#    '129',
#    '3.42',
#    '128',
#    '133'],
#   ['Cyprus',
#    '58',
#    '4.31',
#    '58',
#    '58',
#    'Madagascar',
#    '130',
#    '3.41',
#    '129',
#    '132'],
#   ['Romania',
#    '59',
#    '4.30',
#    '59',
#    '76',
#    'Venezuela',
#    '131',
#    '3.32',
#    '130',
#    '134'],
#   ['Hungary', '60', '4.28', '60', '63', 'Malawi', '132', '3.25', '131', '136'],
#   ['Mexico',
#    '61',
#    '4.27',
#    '61',
#    '55',
#    'Mozambique',
#    '133',
#    '3.24',
#    '132',
#    '137'],
#   ['Rwanda', '62', '4.27', '62', '66', 'Myanmar', '134', '3.24', '133', '139'],
#   ['Macedonia, FYR',
#    '63',
#    '4.26',
#    '63',
#    '73',
#    'Burkina Faso',
#    '135',
#    '3.21',
#    '134',
#    '140'],
#   ['Jordan',
#    '64',
#    '4.25',
#    '64',
#    '68',
#    'Timor-Leste',
#    '136',
#    '3.17',
#    '135',
#    '138'],
#   ['Peru', '65', '4.24', '65', '61', 'Haiti', '137', '3.14', '136', '143'],
#   ['Colombia',
#    '66',
#    '4.23',
#    '66',
#    '69',
#    'Sierra Leone',
#    '138',
#    '3.10',
#    '137',
#    '144'],
#   ['Montenegro',
#    '67',
#    '4.23',
#    '67',
#    '67',
#    'Burundi',
#    '139',
#    '3.09',
#    '138',
#    '146'],
#   ['Vietnam', '68', '4.23', '68', '70', 'Angola', '140', '3.04', '139', '142'],
#   ['Georgia',
#    '69',
#    '4.22',
#    '69',
#    '72',
#    'Mauritania',
#    '141',
#    '3.00',
#    '140',
#    '141'],
#   ['Slovenia', '70', '4.22', '70', '62', 'Yemen', '142', '2.96', '141', '145'],
#   ['India', '71', '4.21', '71', '60', 'Chad', '143', '2.85', '142', '148'],
#   ['Morocco',
#    '72',
#    '4.21',
#    '72',
#    '77',
#    'Guinea',
#    '144',
#    '2.79',
#    '143',
#    '147']],
#  <pdftables.pdftables.TableDiagnosticData at 0x7f71b90e97b8>)

# %%
table[0]
# Out:
# [['',
#   '',
#   '',
#   'Rank among ',
#   'GCI 2013–',
#   '',
#   '',
#   '',
#   'Rank among ',
#   'GCI 2013–'],
#  ['Country/Economy',
#   'Rank (out of 144)',
#   'Score  (1–7)',
#   '2013–2014 economies*',
#   '2014 rank  (out of 148)†',
#   'Country/Economy',
#   'Rank (out of 144)',
#   'Score  (1–7)',
#   '2013–2014 economies*',
#   '2014 rank  (out of 148)†'],
#  ['Switzerland', '1', '5.70', '1', '1', 'Sri Lanka', '73', '4.19', '73', '65'],
#  ['Singapore', '2', '5.65', '2', '2', 'Botswana', '74', '4.15', '74', '74'],
#  ['United States',
#   '3',
#   '5.54',
#   '3',
#   '5',
#   'Slovak Republic',
#   '75',
#   '4.15',
#   '75',
#   '78'],
#  ['Finland', '4', '5.50', '4', '3', 'Ukraine', '76', '4.14', '76', '84'],
#  ['Germany', '5', '5.49', '5', '4', 'Croatia', '77', '4.13', '77', '75'],
#  ['Japan', '6', '5.47', '6', '9', 'Guatemala', '78', '4.10', '78', '86'],
#  ['Hong Kong SAR',
#   '7',
#   '5.46',
#   '7',
#   '7',
#   'Algeria',
#   '79',
#   '4.08',
#   '79',
#   '100'],
#  ['Netherlands', '8', '5.45', '8', '8', 'Uruguay', '80', '4.04', '80', '85'],
#  ['United Kingdom',
#   '9',
#   '5.41',
#   '9',
#   '10',
#   'Greece',
#   '81',
#   '4.04',
#   '81',
#   '91'],
#  ['Sweden', '10', '5.41', '10', '6', 'Moldova', '82', '4.03', '82', '89'],
#  ['Norway',
#   '11',
#   '5.35',
#   '11',
#   '11',
#   'Iran, Islamic Rep.',
#   '83',
#   '4.03',
#   '83',
#   '82'],
#  ['United Arab Emirates',
#   '12',
#   '5.33',
#   '12',
#   '19',
#   'El Salvador',
#   '84',
#   '4.01',
#   '84',
#   '97'],
#  ['Denmark', '13', '5.29', '13', '15', 'Armenia', '85', '4.01', '85', '79'],
#  ['Taiwan, China',
#   '14',
#   '5.25',
#   '14',
#   '12',
#   'Jamaica',
#   '86',
#   '3.98',
#   '86',
#   '94'],
#  ['Canada', '15', '5.24', '15', '14', 'Tunisia', '87', '3.96', '87', '83'],
#  ['Qatar', '16', '5.24', '16', '13', 'Namibia', '88', '3.96', '88', '90'],
#  ['New Zealand',
#   '17',
#   '5.20',
#   '17',
#   '18',
#   'Trinidad and Tobago',
#   '89',
#   '3.95',
#   '89',
#   '92'],
#  ['Belgium', '18', '5.18', '18', '17', 'Kenya', '90', '3.93', '90', '96'],
#  ['Luxembourg',
#   '19',
#   '5.17',
#   '19',
#   '22',
#   'Tajikistan',
#   '91',
#   '3.93',
#   'n/a',
#   'n/a'],
#  ['Malaysia',
#   '20',
#   '5.16',
#   '20',
#   '24',
#   'Seychelles',
#   '92',
#   '3.91',
#   '91',
#   '80'],
#  ['Austria', '21', '5.16', '21', '16', 'Lao PDR', '93', '3.91', '92', '81'],
#  ['Australia', '22', '5.08', '22', '21', 'Serbia', '94', '3.90', '93', '101'],
#  ['France', '23', '5.08', '23', '23', 'Cambodia', '95', '3.89', '94', '88'],
#  ['Saudi Arabia',
#   '24',
#   '5.06',
#   '24',
#   '20',
#   'Zambia',
#   '96',
#   '3.86',
#   '95',
#   '93'],
#  ['Ireland', '25', '4.98', '25', '28', 'Albania', '97', '3.84', '96', '95'],
#  ['Korea, Rep.',
#   '26',
#   '4.96',
#   '26',
#   '25',
#   'Mongolia',
#   '98',
#   '3.83',
#   '97',
#   '107'],
#  ['Israel', '27', '4.95', '27', '27', 'Nicaragua', '99', '3.82', '98', '99'],
#  ['China', '28', '4.89', '28', '29', 'Honduras', '100', '3.82', '99', '111'],
#  ['Estonia',
#   '29',
#   '4.71',
#   '29',
#   '32',
#   'Dominican Republic',
#   '101',
#   '3.82',
#   '100',
#   '105'],
#  ['Iceland', '30', '4.71', '30', '31', 'Nepal', '102', '3.81', '101', '117'],
#  ['Thailand', '31', '4.66', '31', '37', 'Bhutan', '103', '3.80', '102', '109'],
#  ['Puerto Rico',
#   '32',
#   '4.64',
#   '32',
#   '30',
#   'Argentina',
#   '104',
#   '3.79',
#   '103',
#   '104'],
#  ['Chile', '33', '4.60', '33', '34', 'Bolivia', '105', '3.77', '104', '98'],
#  ['Indonesia', '34', '4.57', '34', '38', 'Gabon', '106', '3.74', '105', '112'],
#  ['Spain', '35', '4.55', '35', '35', 'Lesotho', '107', '3.73', '106', '123'],
#  ['Portugal',
#   '36',
#   '4.54',
#   '36',
#   '51',
#   'Kyrgyz Republic',
#   '108',
#   '3.73',
#   '107',
#   '121'],
#  ['Czech Republic',
#   '37',
#   '4.53',
#   '37',
#   '46',
#   'Bangladesh',
#   '109',
#   '3.72',
#   '108',
#   '110'],
#  ['Azerbaijan',
#   '38',
#   '4.53',
#   '38',
#   '39',
#   'Suriname',
#   '110',
#   '3.71',
#   '109',
#   '106'],
#  ['Mauritius', '39', '4.52', '39', '45', 'Ghana', '111', '3.71', '110', '114'],
#  ['Kuwait', '40', '4.51', '40', '36', 'Senegal', '112', '3.70', '111', '113'],
#  ['Lithuania',
#   '41',
#   '4.51',
#   '41',
#   '48',
#   'Lebanon',
#   '113',
#   '3.68',
#   '112',
#   '103'],
#  ['Latvia',
#   '42',
#   '4.50',
#   '42',
#   '52',
#   'Cape Verde',
#   '114',
#   '3.68',
#   '113',
#   '122'],
#  ['Poland',
#   '43',
#   '4.48',
#   '43',
#   '42',
#   "Côte d'Ivoire",
#   '115',
#   '3.67',
#   '114',
#   '126'],
#  ['Bahrain',
#   '44',
#   '4.48',
#   '44',
#   '43',
#   'Cameroon',
#   '116',
#   '3.66',
#   '115',
#   '115'],
#  ['Turkey', '45', '4.46', '45', '44', 'Guyana', '117', '3.65', '116', '102'],
#  ['Oman', '46', '4.46', '46', '33', 'Ethiopia', '118', '3.60', '117', '127'],
#  ['Malta', '47', '4.45', '47', '41', 'Egypt', '119', '3.60', '118', '118'],
#  ['Panama', '48', '4.43', '48', '40', 'Paraguay', '120', '3.59', '119', '119'],
#  ['Italy', '49', '4.42', '49', '49', 'Tanzania', '121', '3.57', '120', '125'],
#  ['Kazakhstan',
#   '50',
#   '4.42',
#   '50',
#   '50',
#   'Uganda',
#   '122',
#   '3.56',
#   '121',
#   '129'],
#  ['Costa Rica',
#   '51',
#   '4.42',
#   '51',
#   '54',
#   'Swaziland',
#   '123',
#   '3.55',
#   '122',
#   '124'],
#  ['Philippines',
#   '52',
#   '4.40',
#   '52',
#   '59',
#   'Zimbabwe',
#   '124',
#   '3.54',
#   '123',
#   '131'],
#  ['Russian Federation',
#   '53',
#   '4.37',
#   '53',
#   '64',
#   'Gambia, The',
#   '125',
#   '3.53',
#   '124',
#   '116'],
#  ['Bulgaria', '54', '4.37', '54', '57', 'Libya', '126', '3.48', '125', '108'],
#  ['Barbados',
#   '55',
#   '4.36',
#   '55',
#   '47',
#   'Nigeria',
#   '127',
#   '3.44',
#   '126',
#   '120'],
#  ['South Africa',
#   '56',
#   '4.35',
#   '56',
#   '53',
#   'Mali',
#   '128',
#   '3.43',
#   '127',
#   '135'],
#  ['Brazil', '57', '4.34', '57', '56', 'Pakistan', '129', '3.42', '128', '133'],
#  ['Cyprus',
#   '58',
#   '4.31',
#   '58',
#   '58',
#   'Madagascar',
#   '130',
#   '3.41',
#   '129',
#   '132'],
#  ['Romania',
#   '59',
#   '4.30',
#   '59',
#   '76',
#   'Venezuela',
#   '131',
#   '3.32',
#   '130',
#   '134'],
#  ['Hungary', '60', '4.28', '60', '63', 'Malawi', '132', '3.25', '131', '136'],
#  ['Mexico',
#   '61',
#   '4.27',
#   '61',
#   '55',
#   'Mozambique',
#   '133',
#   '3.24',
#   '132',
#   '137'],
#  ['Rwanda', '62', '4.27', '62', '66', 'Myanmar', '134', '3.24', '133', '139'],
#  ['Macedonia, FYR',
#   '63',
#   '4.26',
#   '63',
#   '73',
#   'Burkina Faso',
#   '135',
#   '3.21',
#   '134',
#   '140'],
#  ['Jordan',
#   '64',
#   '4.25',
#   '64',
#   '68',
#   'Timor-Leste',
#   '136',
#   '3.17',
#   '135',
#   '138'],
#  ['Peru', '65', '4.24', '65', '61', 'Haiti', '137', '3.14', '136', '143'],
#  ['Colombia',
#   '66',
#   '4.23',
#   '66',
#   '69',
#   'Sierra Leone',
#   '138',
#   '3.10',
#   '137',
#   '144'],
#  ['Montenegro',
#   '67',
#   '4.23',
#   '67',
#   '67',
#   'Burundi',
#   '139',
#   '3.09',
#   '138',
#   '146'],
#  ['Vietnam', '68', '4.23', '68', '70', 'Angola', '140', '3.04', '139', '142'],
#  ['Georgia',
#   '69',
#   '4.22',
#   '69',
#   '72',
#   'Mauritania',
#   '141',
#   '3.00',
#   '140',
#   '141'],
#  ['Slovenia', '70', '4.22', '70', '62', 'Yemen', '142', '2.96', '141', '145'],
#  ['India', '71', '4.21', '71', '60', 'Chad', '143', '2.85', '142', '148'],
#  ['Morocco', '72', '4.21', '72', '77', 'Guinea', '144', '2.79', '143', '147']]

# %%
table[0][0]
# Out:
# ['',
#  '',
#  '',
#  'Rank among ',
#  'GCI 2013–',
#  '',
#  '',
#  '',
#  'Rank among ',
#  'GCI 2013–']

# %%
table[0][1]
# Out:
# ['Country/Economy',
#  'Rank (out of 144)',
#  'Score  (1–7)',
#  '2013–2014 economies*',
#  '2014 rank  (out of 148)†',
#  'Country/Economy',
#  'Rank (out of 144)',
#  'Score  (1–7)',
#  '2013–2014 economies*',
#  '2014 rank  (out of 148)†']

# %%
titles = list(zip(table[0][0], table[0][1]))[:5]

# %%
titles
# Out:
# [('', 'Country/Economy'),
#  ('', 'Rank (out of 144)'),
#  ('', 'Score  (1–7)'),
#  ('Rank among ', '2013–2014 economies*'),
#  ('GCI 2013–', '2014 rank  (out of 148)†')]

# %%
titles = [''.join([title[0], title[1]]) for title in titles]
print(titles)
# Out:
# ['Country/Economy', 'Rank (out of 144)', 'Score  (1–7)', 'Rank among 2013–2014 economies*', 'GCI 2013–2014 rank  (out of 148)†']

# %%
all_rows = []
for row_data in table[0][2:]:
    all_rows.extend([row_data[:5], row_data[5:]])

# %%
all_rows
# Out:
# [['Switzerland', '1', '5.70', '1', '1'],
#  ['Sri Lanka', '73', '4.19', '73', '65'],
#  ['Singapore', '2', '5.65', '2', '2'],
#  ['Botswana', '74', '4.15', '74', '74'],
#  ['United States', '3', '5.54', '3', '5'],
#  ['Slovak Republic', '75', '4.15', '75', '78'],
#  ['Finland', '4', '5.50', '4', '3'],
#  ['Ukraine', '76', '4.14', '76', '84'],
#  ['Germany', '5', '5.49', '5', '4'],
#  ['Croatia', '77', '4.13', '77', '75'],
#  ['Japan', '6', '5.47', '6', '9'],
#  ['Guatemala', '78', '4.10', '78', '86'],
#  ['Hong Kong SAR', '7', '5.46', '7', '7'],
#  ['Algeria', '79', '4.08', '79', '100'],
#  ['Netherlands', '8', '5.45', '8', '8'],
#  ['Uruguay', '80', '4.04', '80', '85'],
#  ['United Kingdom', '9', '5.41', '9', '10'],
#  ['Greece', '81', '4.04', '81', '91'],
#  ['Sweden', '10', '5.41', '10', '6'],
#  ['Moldova', '82', '4.03', '82', '89'],
#  ['Norway', '11', '5.35', '11', '11'],
#  ['Iran, Islamic Rep.', '83', '4.03', '83', '82'],
#  ['United Arab Emirates', '12', '5.33', '12', '19'],
#  ['El Salvador', '84', '4.01', '84', '97'],
#  ['Denmark', '13', '5.29', '13', '15'],
#  ['Armenia', '85', '4.01', '85', '79'],
#  ['Taiwan, China', '14', '5.25', '14', '12'],
#  ['Jamaica', '86', '3.98', '86', '94'],
#  ['Canada', '15', '5.24', '15', '14'],
#  ['Tunisia', '87', '3.96', '87', '83'],
#  ['Qatar', '16', '5.24', '16', '13'],
#  ['Namibia', '88', '3.96', '88', '90'],
#  ['New Zealand', '17', '5.20', '17', '18'],
#  ['Trinidad and Tobago', '89', '3.95', '89', '92'],
#  ['Belgium', '18', '5.18', '18', '17'],
#  ['Kenya', '90', '3.93', '90', '96'],
#  ['Luxembourg', '19', '5.17', '19', '22'],
#  ['Tajikistan', '91', '3.93', 'n/a', 'n/a'],
#  ['Malaysia', '20', '5.16', '20', '24'],
#  ['Seychelles', '92', '3.91', '91', '80'],
#  ['Austria', '21', '5.16', '21', '16'],
#  ['Lao PDR', '93', '3.91', '92', '81'],
#  ['Australia', '22', '5.08', '22', '21'],
#  ['Serbia', '94', '3.90', '93', '101'],
#  ['France', '23', '5.08', '23', '23'],
#  ['Cambodia', '95', '3.89', '94', '88'],
#  ['Saudi Arabia', '24', '5.06', '24', '20'],
#  ['Zambia', '96', '3.86', '95', '93'],
#  ['Ireland', '25', '4.98', '25', '28'],
#  ['Albania', '97', '3.84', '96', '95'],
#  ['Korea, Rep.', '26', '4.96', '26', '25'],
#  ['Mongolia', '98', '3.83', '97', '107'],
#  ['Israel', '27', '4.95', '27', '27'],
#  ['Nicaragua', '99', '3.82', '98', '99'],
#  ['China', '28', '4.89', '28', '29'],
#  ['Honduras', '100', '3.82', '99', '111'],
#  ['Estonia', '29', '4.71', '29', '32'],
#  ['Dominican Republic', '101', '3.82', '100', '105'],
#  ['Iceland', '30', '4.71', '30', '31'],
#  ['Nepal', '102', '3.81', '101', '117'],
#  ['Thailand', '31', '4.66', '31', '37'],
#  ['Bhutan', '103', '3.80', '102', '109'],
#  ['Puerto Rico', '32', '4.64', '32', '30'],
#  ['Argentina', '104', '3.79', '103', '104'],
#  ['Chile', '33', '4.60', '33', '34'],
#  ['Bolivia', '105', '3.77', '104', '98'],
#  ['Indonesia', '34', '4.57', '34', '38'],
#  ['Gabon', '106', '3.74', '105', '112'],
#  ['Spain', '35', '4.55', '35', '35'],
#  ['Lesotho', '107', '3.73', '106', '123'],
#  ['Portugal', '36', '4.54', '36', '51'],
#  ['Kyrgyz Republic', '108', '3.73', '107', '121'],
#  ['Czech Republic', '37', '4.53', '37', '46'],
#  ['Bangladesh', '109', '3.72', '108', '110'],
#  ['Azerbaijan', '38', '4.53', '38', '39'],
#  ['Suriname', '110', '3.71', '109', '106'],
#  ['Mauritius', '39', '4.52', '39', '45'],
#  ['Ghana', '111', '3.71', '110', '114'],
#  ['Kuwait', '40', '4.51', '40', '36'],
#  ['Senegal', '112', '3.70', '111', '113'],
#  ['Lithuania', '41', '4.51', '41', '48'],
#  ['Lebanon', '113', '3.68', '112', '103'],
#  ['Latvia', '42', '4.50', '42', '52'],
#  ['Cape Verde', '114', '3.68', '113', '122'],
#  ['Poland', '43', '4.48', '43', '42'],
#  ["Côte d'Ivoire", '115', '3.67', '114', '126'],
#  ['Bahrain', '44', '4.48', '44', '43'],
#  ['Cameroon', '116', '3.66', '115', '115'],
#  ['Turkey', '45', '4.46', '45', '44'],
#  ['Guyana', '117', '3.65', '116', '102'],
#  ['Oman', '46', '4.46', '46', '33'],
#  ['Ethiopia', '118', '3.60', '117', '127'],
#  ['Malta', '47', '4.45', '47', '41'],
#  ['Egypt', '119', '3.60', '118', '118'],
#  ['Panama', '48', '4.43', '48', '40'],
#  ['Paraguay', '120', '3.59', '119', '119'],
#  ['Italy', '49', '4.42', '49', '49'],
#  ['Tanzania', '121', '3.57', '120', '125'],
#  ['Kazakhstan', '50', '4.42', '50', '50'],
#  ['Uganda', '122', '3.56', '121', '129'],
#  ['Costa Rica', '51', '4.42', '51', '54'],
#  ['Swaziland', '123', '3.55', '122', '124'],
#  ['Philippines', '52', '4.40', '52', '59'],
#  ['Zimbabwe', '124', '3.54', '123', '131'],
#  ['Russian Federation', '53', '4.37', '53', '64'],
#  ['Gambia, The', '125', '3.53', '124', '116'],
#  ['Bulgaria', '54', '4.37', '54', '57'],
#  ['Libya', '126', '3.48', '125', '108'],
#  ['Barbados', '55', '4.36', '55', '47'],
#  ['Nigeria', '127', '3.44', '126', '120'],
#  ['South Africa', '56', '4.35', '56', '53'],
#  ['Mali', '128', '3.43', '127', '135'],
#  ['Brazil', '57', '4.34', '57', '56'],
#  ['Pakistan', '129', '3.42', '128', '133'],
#  ['Cyprus', '58', '4.31', '58', '58'],
#  ['Madagascar', '130', '3.41', '129', '132'],
#  ['Romania', '59', '4.30', '59', '76'],
#  ['Venezuela', '131', '3.32', '130', '134'],
#  ['Hungary', '60', '4.28', '60', '63'],
#  ['Malawi', '132', '3.25', '131', '136'],
#  ['Mexico', '61', '4.27', '61', '55'],
#  ['Mozambique', '133', '3.24', '132', '137'],
#  ['Rwanda', '62', '4.27', '62', '66'],
#  ['Myanmar', '134', '3.24', '133', '139'],
#  ['Macedonia, FYR', '63', '4.26', '63', '73'],
#  ['Burkina Faso', '135', '3.21', '134', '140'],
#  ['Jordan', '64', '4.25', '64', '68'],
#  ['Timor-Leste', '136', '3.17', '135', '138'],
#  ['Peru', '65', '4.24', '65', '61'],
#  ['Haiti', '137', '3.14', '136', '143'],
#  ['Colombia', '66', '4.23', '66', '69'],
#  ['Sierra Leone', '138', '3.10', '137', '144'],
#  ['Montenegro', '67', '4.23', '67', '67'],
#  ['Burundi', '139', '3.09', '138', '146'],
#  ['Vietnam', '68', '4.23', '68', '70'],
#  ['Angola', '140', '3.04', '139', '142'],
#  ['Georgia', '69', '4.22', '69', '72'],
#  ['Mauritania', '141', '3.00', '140', '141'],
#  ['Slovenia', '70', '4.22', '70', '62'],
#  ['Yemen', '142', '2.96', '141', '145'],
#  ['India', '71', '4.21', '71', '60'],
#  ['Chad', '143', '2.85', '142', '148'],
#  ['Morocco', '72', '4.21', '72', '77'],
#  ['Guinea', '144', '2.79', '143', '147']]

# %%
df = pd.DataFrame(all_rows, columns=titles)

# %%
df.head()
# Out:
#   Country/Economy Rank (out of 144) Score  (1–7)  \
# 0     Switzerland                 1         5.70
# 1       Sri Lanka                73         4.19
# 2       Singapore                 2         5.65
# 3        Botswana                74         4.15
# 4   United States                 3         5.54
#
#   Rank among 2013–2014 economies* GCI 2013–2014 rank  (out of 148)†
# 0                               1                                 1
# 1                              73                                65
# 2                               2                                 2
# 3                              74                                74
# 4                               3                                 5

# %% [markdown]
# ### Your turn: Try with page 30, 31 or 32

# %%
new_chart_page = pdftables.get_pdf_page(my_pdf, 30)

# %%
table = pdftables.page_to_tables(new_chart_page)

# %%
table[0]
