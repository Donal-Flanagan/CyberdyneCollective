# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math


0 ≤ a ≤ 1
0 ≤ b ≤ 7
0 ≤ c ≤ 5
0 ≤ d ≤ 1
# Out:
# /home/donal/cyberdyne/rejewski/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/donal/cyberdyne/rejewski/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def gaussian(x, mu=0.5, sig=0.1):
    ''' 
    mu = mean (midpoint)
    sig = variance (width)
    '''
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))


'''
A sin(xw)

A - Amplitude
x - position
w - Frequency
'''

def test_function_a(a):
    (A_r, w_r) = (0.5, 10)
    (A_p, w_p) = (0.5, 3)
    
    r = A_r*np.sin(x*w_r) + 0.4*gaussian(x, mu=0.6, sig=0.3) + 0.1
    p = A_p*np.sin(x*w_p-0.1) + 0.5
    q = 2*np.sin(x*20) + 3*np.sin(x*5) + 10
    
    plt.plot(x, r)
    plt.plot(x, p)
    # plt.plot(x, q)
    plt.show()
    
    return r, p, q

x = np.linspace(0, 1, 100)
r, p, q = test_function_a(x)

fig = plt.figure()
    ax = plt.subplot()
    
    ax.plot(x, r, label='recall')
    ax.plot(x, p, label='precision')
    ax.plot(x, q, label='question')
    ax.legend()
    plt.show()
# Out:
#   File "<ipython-input-3-00b1fa2440da>", line 36
#     ax = plt.subplot
#     ^
# IndentationError: unexpected indent

# %%
#q = A_q*np.sin(x*w_q) + 10*np.sin(x*10+5) 
x = np.linspace(0, 1, 100)

r = 2*np.sin(x*20) + 2
p = 3*np.sin(x*5) + 3
plt.plot(x, r)
plt.plot(x, p)
plt.plot(x, r+p+5)

q = 2*np.sin(x*20) + 3*np.sin(x*5) + 10
plt.plot(x, q)

plt.show()

# %%
A_r = 0.5
w_r = 4
x = np.linspace(0, 1, 100)

r = A_r*np.sinc(x*w_r) + 0.5
plt.plot(x, r)

plt.show()

# %%
x = np.linspace(0, 1, 100)
h = np.heaviside(x-0.5, 0.5)*5
plt.plot(x, h)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-4545cd586fd5> in <module>()
#       1 x = np.linspace(0, 1, 100)
# ----> 2 h = np.heaviside(x-0.5, 0.5)*5
#       3 plt.plot(x, h)
#
# AttributeError: module 'numpy' has no attribute 'heaviside'
